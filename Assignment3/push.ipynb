# %%
# !git add .
# !git commit -m "RNN"
# !git push origin main
# Out:
# ...
# [main a9fc549] RNN
#  9 files changed, 39 insertions(+)
#  create mode 100644 Assignment3/hate/hate_rnn_loss_accuracy_plot.png
#  create mode 100644 Assignment3/hate/hate_rnn_model.pt
#  create mode 100644 Assignment3/humor.zip
#  create mode 100644 Assignment3/humor/humor_rnn_loss_accuracy_plot.png
#  create mode 100644 Assignment3/humor/humor_rnn_model.pt
#  create mode 100644 Assignment3/push.ipynb
#  create mode 100644 Assignment3/sarcasm.zip
#  create mode 100644 Assignment3/sarcasm/sarcasm_rnn_loss_accuracy_plot.png
#  create mode 100644 Assignment3/sarcasm/sarcasm_rnn_model.pt
# To https://github.com/sinhajiya/DSE318-NLP-Assignment-Solutions.git
#    dabb978..a9fc549  main -> main
